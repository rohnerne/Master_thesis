# %% [markdown]
# # Loading Neuron Simulation Results
# Neuron simulations from monopolar electromagnetic (=EM) simulations. (No AF with threshold as it is done for multipolar configurations).
# Same approach as Rowald*, Komi*, Demesmaeker* et al. 2022.
# Due to the fact that the code was poorly mantained and not transmited, this part of the pipeline needed to be coded again.
#
# Author: Sergio Daniel Hernandez Charpak
#
# December 2022

# %%
# To load and save files
import os
import glob
import pickle
# to form the table
import pandas as pd
import numpy as np

# %%
def combine_concatenate_two_string_arrays(array_1,array_2,n_arrays=2,sep_string="_"):
	"""
    Given two arrays of strings, it computes all the different combinations of
    arrays[item_array_1, item_array_2] and then form the array of the concatenation
    of these two times [item_array_1"sep"item_array_2].
    @returns array of strings [item_i_array_1"sep"item_j_array_2]
    """
	comb_array = np.array(np.meshgrid(array_1, array_2)).T.reshape(-1,n_arrays)
	folders_to_iterate=[]
	for combination in comb_array:
		folder=""
		n_items_to_combine=len(combination)
		folder+=combination[0]
		for i in range(1,n_items_to_combine):
			folder+=(sep_string+combination[i])
		folders_to_iterate.append(folder)
	return folders_to_iterate

# %%
folder_output="/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/Processed_12_2022"

# %%
folder_raw_results="/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse"
# !ls $folder_raw_results
# Out:
# senn_single_pulse - GO_E00 senn_single_pulse - GO_E08
# senn_single_pulse - GO_E01 senn_single_pulse - GO_E09
# senn_single_pulse - GO_E02 senn_single_pulse - GO_E10
# senn_single_pulse - GO_E03 senn_single_pulse - GO_E11
# senn_single_pulse - GO_E04 senn_single_pulse - GO_E12
# senn_single_pulse - GO_E05 senn_single_pulse - GO_E13
# senn_single_pulse - GO_E06 senn_single_pulse - GO_E14
# senn_single_pulse - GO_E07 senn_single_pulse - GO_E15

# %% [markdown]
# Each subfolder contains the neuron simulation for each monopolar EM simulation.
# We know in this case the subject and the lead which was used.

# %%
subject='MR012'
lead='GO2'
electrodes=["E"+str(i).zfill(2) for i in range(16)]

# %%
electrodes
# Out:
# ['E00',
#  'E01',
#  'E02',
#  'E03',
#  'E04',
#  'E05',
#  'E06',
#  'E07',
#  'E08',
#  'E09',
#  'E10',
#  'E11',
#  'E12',
#  'E13',
#  'E14',
#  'E15']

# %%
folder_raw_results_for_listing=os.path.join(folder_raw_results,'*')
subfolder_list=glob.glob(folder_raw_results_for_listing)

# %%
subfolder_list
# Out:
# ['/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E00',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E01',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E02',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E03',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E04',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E05',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E06',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E07',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E08',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E09',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E10',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E11',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E12',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E13',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E14',
#  '/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/senn_single_pulse/senn_single_pulse - GO_E15']

# %%
electrodes_from_listing=[folder_i[-3:] for folder_i in subfolder_list]

# %%
n_monopolar_sims=len(electrodes_from_listing)

# %% [markdown]
# ## Exploration
# We explore one sim and one file to see how it is structred

# %%
i_monopolar_sim=0

# %%
monopolar_sim_i=electrodes_from_listing[i_monopolar_sim]
monopolar_sim_sub_folder_i=subfolder_list[i_monopolar_sim]

# %%
folder_files_monopolar_sim_sub_folder_i=os.path.join(monopolar_sim_sub_folder_i,'csv')
folder_files_monopolar_sim_sub_folder_i_for_listing=os.path.join(folder_files_monopolar_sim_sub_folder_i,"*")
files_monopolar_sim_sub_folder_i=glob.glob(folder_files_monopolar_sim_sub_folder_i_for_listing)

# %%
# All the files for one ELectrode
files_monopolar_sim_sub_folder_i

# %%
n_total_fibers=len(files_monopolar_sim_sub_folder_i)

# %%
i_fiber_sim=0

# %%
file_fiber_i_sim=files_monopolar_sim_sub_folder_i[i_fiber_sim]

# %%
df_fiber_i_sim=pd.read_csv(file_fiber_i_sim,sep=",")

# %%
# All fibres per rootlet
df_fiber_i_sim.head(50)
# Out:
#                                          Neuron Name Location of First Spike  \
# 0  L1_DL_rlet_1_fibers_1 [SENN Neuron 12.00um]  (...                node[56]
# 1  L1_DL_rlet_1_fibers_10 [SENN Neuron 20.00um]  ...                node[33]
# 2  L1_DL_rlet_1_fibers_2 [SENN Neuron 12.89um]  (...                node[52]
# 3  L1_DL_rlet_1_fibers_3 [SENN Neuron 13.78um]  (...                node[50]
# 4  L1_DL_rlet_1_fibers_4 [SENN Neuron 14.67um]  (...                node[45]
# 5  L1_DL_rlet_1_fibers_5 [SENN Neuron 15.56um]  (...                node[43]
# 6  L1_DL_rlet_1_fibers_6 [SENN Neuron 16.44um]  (...                node[41]
# 7  L1_DL_rlet_1_fibers_7 [SENN Neuron 17.33um]  (...                node[38]
# 8  L1_DL_rlet_1_fibers_8 [SENN Neuron 18.22um]  (...           internode[37]
# 9  L1_DL_rlet_1_fibers_9 [SENN Neuron 19.11um]  (...                node[33]
#
#    Time of First Spike (ms)  Titration Factor
# 0                  0.000260             160.0
# 1                  0.000192              63.0
# 2                  0.000228             126.0
# 3                  0.000250             107.0
# 4                  0.000290             144.0
# 5                  0.000253              91.5
# 6                  0.000215             114.0
# 7                  0.000275              79.0
# 8                  0.000212              99.5
# 9                  0.000210              68.0

# %%
df_fiber_i_sim.columns
# Out:
# Index(['Neuron Name', 'Location of First Spike', 'Time of First Spike (ms)',
#        'Titration Factor'],
#       dtype='object')

# %% [markdown]
# We are mostly interested by the Tritration factor of each fiber. This is the key value to keep. For each tritration factor, fibers with a tritration factor smaller or equal to this value will count as active. For each factor we can then count the number of fibers active and the number of fibers inactive. These will be the values used to compute the recruitment percentages.
#
# In here each file contains the information for each rootlet (10 fibers per rootlet).
#
#
# We now have to :
# * Get all this information in a dataframe.
# * Find the maximum overall tritration factor of the simulation (for each monopolar electrode)
# * Find for each **Root** (not rootlet) the max tritration factor
# * Do the counting of active fibers and inactive fibers
# * Compute the recruitment

# %% [markdown]
# Found the method (implemented by Edoardo/Andreas):
# ```
# Fiber_List = []
# for root_idx, root_val in enumerate(Root_Name):
#     for quad_idx,quad_val in enumerate(Quad_Name):
#         for type_idx,type_val in enumerate(Type_Name):
#             Fiber_List.append(root_val + '-' + quad_val + '_' + type_val)
#
# for design in designs:
#     for electrode in electrodes:
#
#         filefolder = join(folderpath,design,electrode,'csv')
#         titration_axes = [] # list holding titration factor from roots
#         recruitment_percentage = [] # list holding recruitment percentage from roots
#         for f_1 in Fiber_List:
#             print f_1
#             f = join(filefolder,'Titration_Sweeney - '+electrode+'_'+f_1+'.csv')
#             titration_list = np.genfromtxt(join(filefolder,f), delimiter=',', skip_header=1)
#             titration_list = titration_list[:,3] #remove later
#             tdiv = np.linspace(np.min(titration_list), np.max(titration_list), datapoints) #number of data points
#             rec=[]
#             for t in tdiv:
#                 cn=0
#                 for tit in titration_list:
#                     if tit<=t:
#                         cn+=1
#                 rec.append(cn)
#             rec=np.array(rec)
#             percentage_rec = 100.*rec/n
#
#             titration_axes.append(tdiv)
#             recruitment_percentage.append(percentage_rec)
# ```

# %% [markdown]
# ## Loading
# Let us now load everything into one dataframe

# %%
spinal_levels=["T12","L1","L2","L3","L4","L5","S1","S2","S3","S4"]
quadrants=["DL","DR"]
roots=combine_concatenate_two_string_arrays(spinal_levels,quadrants,n_arrays=2,sep_string="_")
n_roots=len(roots)

# %%
list_dfs_monopolar_sims=[]
# Loop on the monopolar sims/electrodes
for i_monopolar_sim in range(n_monopolar_sims):
    monopolar_sim_i=electrodes_from_listing[i_monopolar_sim]
    monopolar_sim_sub_folder_i=subfolder_list[i_monopolar_sim]
    folder_files_monopolar_sim_sub_folder_i=os.path.join(monopolar_sim_sub_folder_i,'csv')
    folder_files_monopolar_sim_sub_folder_i_for_listing=os.path.join(folder_files_monopolar_sim_sub_folder_i,"*")
    files_monopolar_sim_sub_folder_i=glob.glob(folder_files_monopolar_sim_sub_folder_i_for_listing)
    n_total_fibers=len(files_monopolar_sim_sub_folder_i)
    # Loop on the fibers from the file (fibers per rootlet)
    for i_fiber_sim in range(n_total_fibers):
        file_fiber_i_sim=files_monopolar_sim_sub_folder_i[i_fiber_sim]
        df_fiber_i_sim=pd.read_csv(file_fiber_i_sim,sep=",")
        # Find out which root it belongs to 
        # Gets a neuron name
        name_first_fiber_df_fiber_i_sim= df_fiber_i_sim['Neuron Name'][0]
        root_df_fiber_i=""
        for root_i in roots:
            if root_i in name_first_fiber_df_fiber_i_sim:
                root_df_fiber_i=root_i
                break
        df_fiber_i_sim['Root']=root_df_fiber_i
        spinal_level_df_fiber_i=""
        quadrant_df_fiber_i=""
        for spinal_level_i in spinal_levels:
            if spinal_level_i in root_df_fiber_i:
                spinal_level_df_fiber_i=spinal_level_i
                break
        df_fiber_i_sim['Spinal_Level']=spinal_level_df_fiber_i
        for quadrant_i in quadrants:
            if quadrant_i in root_df_fiber_i:
                quadrant_df_fiber_i=quadrant_i
                break
        df_fiber_i_sim['Quadrant']=quadrant_df_fiber_i
        df_fiber_i_sim['EM_Sim']=monopolar_sim_i
        list_dfs_monopolar_sims.append(df_fiber_i_sim)
# Concat everything into one df
df_neuron_sim=pd.concat(list_dfs_monopolar_sims,ignore_index=True)

# %%
df_neuron_sim.head(20)
# Out:
#                                           Neuron Name Location of First Spike  \
# 0   L1_DL_rlet_1_fibers_1 [SENN Neuron 12.00um]  (...                node[56]
# 1   L1_DL_rlet_1_fibers_10 [SENN Neuron 20.00um]  ...                node[33]
# 2   L1_DL_rlet_1_fibers_2 [SENN Neuron 12.89um]  (...                node[52]
# 3   L1_DL_rlet_1_fibers_3 [SENN Neuron 13.78um]  (...                node[50]
# 4   L1_DL_rlet_1_fibers_4 [SENN Neuron 14.67um]  (...                node[45]
# 5   L1_DL_rlet_1_fibers_5 [SENN Neuron 15.56um]  (...                node[43]
# 6   L1_DL_rlet_1_fibers_6 [SENN Neuron 16.44um]  (...                node[41]
# 7   L1_DL_rlet_1_fibers_7 [SENN Neuron 17.33um]  (...                node[38]
# 8   L1_DL_rlet_1_fibers_8 [SENN Neuron 18.22um]  (...           internode[37]
# 9   L1_DL_rlet_1_fibers_9 [SENN Neuron 19.11um]  (...                node[33]
# 10  L1_DL_rlet_2_fibers_1 [SENN Neuron 12.00um]  (...                node[56]
# 11  L1_DL_rlet_2_fibers_10 [SENN Neuron 20.00um]  ...                node[32]
# 12  L1_DL_rlet_2_fibers_2 [SENN Neuron 12.89um]  (...                node[51]
# 13  L1_DL_rlet_2_fibers_3 [SENN Neuron 13.78um]  (...                node[49]
# 14  L1_DL_rlet_2_fibers_4 [SENN Neuron 14.67um]  (...                node[45]
# 15  L1_DL_rlet_2_fibers_5 [SENN Neuron 15.56um]  (...                node[42]
# 16  L1_DL_rlet_2_fibers_6 [SENN Neuron 16.44um]  (...                node[41]
# 17  L1_DL_rlet_2_fibers_7 [SENN Neuron 17.33um]  (...                node[38]
# 18  L1_DL_rlet_2_fibers_8 [SENN Neuron 18.22um]  (...                node[37]
# 19  L1_DL_rlet_2_fibers_9 [SENN Neuron 19.11um]  (...                node[35]
#
#     Time of First Spike (ms)  Titration Factor   Root Spinal_Level Quadrant  \
# 0                   0.000260             160.0  L1_DL           L1       DL
# 1                   0.000192              63.0  L1_DL           L1       DL
# 2                   0.000228             126.0  L1_DL           L1       DL
# 3                   0.000250             107.0  L1_DL           L1       DL
# 4                   0.000290             144.0  L1_DL           L1       DL
# 5                   0.000253              91.5  L1_DL           L1       DL
# 6                   0.000215             114.0  L1_DL           L1       DL
# 7                   0.000275              79.0  L1_DL           L1       DL
# 8                   0.000212              99.5  L1_DL           L1       DL
# 9                   0.000210              68.0  L1_DL           L1       DL
# 10                  0.000258             148.0  L1_DL           L1       DL
# 11                  0.000208              67.0  L1_DL           L1       DL
# 12                  0.000247             133.0  L1_DL           L1       DL
# 13                  0.000195              85.5  L1_DL           L1       DL
# 14                  0.000233             147.0  L1_DL           L1       DL
# 15                  0.000228              96.0  L1_DL           L1       DL
# 16                  0.000200              96.0  L1_DL           L1       DL
# 17                  0.000230              79.5  L1_DL           L1       DL
# 18                  0.000202              92.0  L1_DL           L1       DL
# 19                  0.000208              87.5  L1_DL           L1       DL
#
#    EM_Sim
# 0     E00
# 1     E00
# 2     E00
# 3     E00
# 4     E00
# 5     E00
# 6     E00
# 7     E00
# 8     E00
# 9     E00
# 10    E00
# 11    E00
# 12    E00
# 13    E00
# 14    E00
# 15    E00
# 16    E00
# 17    E00
# 18    E00
# 19    E00

# %%
# Save the resulting dataframe
file_name="Monopolar_MR012_GO2_12_2022.csv"
file_path=os.path.join(folder_output,file_name)
os.makedirs(folder_output,exist_ok=True)
df_neuron_sim.to_csv(file_path)

# %% [markdown]
# ## Recruitment
# Now we get the recruitmnet **per root** for each EM_Sim.

# %%
n_data_points=100 # Number of points which represents the "amplitude"

# %%
# all neurons
#df_neuron_sim_emSim_i
df_neuron_sim[df_neuron_sim['EM_Sim']=='E00']
# Out:
#                                            Neuron Name  \
# 0    L1_DL_rlet_1_fibers_1 [SENN Neuron 12.00um]  (...
# 1    L1_DL_rlet_1_fibers_10 [SENN Neuron 20.00um]  ...
# 2    L1_DL_rlet_1_fibers_2 [SENN Neuron 12.89um]  (...
# 3    L1_DL_rlet_1_fibers_3 [SENN Neuron 13.78um]  (...
# 4    L1_DL_rlet_1_fibers_4 [SENN Neuron 14.67um]  (...
# ..                                                 ...
# 875  T12_DR_rlet_5_fibers_5 [SENN Neuron 15.56um]  ...
# 876  T12_DR_rlet_5_fibers_6 [SENN Neuron 16.44um]  ...
# 877  T12_DR_rlet_5_fibers_7 [SENN Neuron 17.33um]  ...
# 878  T12_DR_rlet_5_fibers_8 [SENN Neuron 18.22um]  ...
# 879  T12_DR_rlet_5_fibers_9 [SENN Neuron 19.11um]  ...
#
#     Location of First Spike  Time of First Spike (ms)  Titration Factor  \
# 0                  node[56]                  0.000260             160.0
# 1                  node[33]                  0.000192              63.0
# 2                  node[52]                  0.000228             126.0
# 3                  node[50]                  0.000250             107.0
# 4                  node[45]                  0.000290             144.0
# ..                      ...                       ...               ...
# 875                node[23]                  0.000218              86.5
# 876                node[22]                  0.000235              67.5
# 877                node[20]                  0.000212              63.5
# 878                node[19]                  0.000210              55.0
# 879                node[18]                  0.000202              57.0
#
#        Root Spinal_Level Quadrant EM_Sim
# 0     L1_DL           L1       DL    E00
# 1     L1_DL           L1       DL    E00
# 2     L1_DL           L1       DL    E00
# 3     L1_DL           L1       DL    E00
# 4     L1_DL           L1       DL    E00
# ..      ...          ...      ...    ...
# 875  T12_DR          T12       DR    E00
# 876  T12_DR          T12       DR    E00
# 877  T12_DR          T12       DR    E00
# 878  T12_DR          T12       DR    E00
# 879  T12_DR          T12       DR    E00
#
# [880 rows x 8 columns]

# %%
# One neuron 
#df_neuron_sim_emSim_i_root_i
df_neuron_sim_emSim_i[df_neuron_sim_emSim_i['Root']=='L1_DL']

# %% [markdown]
# Calculate recruitments

# %%
# Loop through the monopolar EM simulations ( all the electrodes)
# save the results in a class
recruitment_simulation = {}

for i_sim in range(n_monopolar_sims):
# for i_sim in [0]:
    sim_i=electrodes_from_listing[i_sim]
    # Get the results for this particular simulation (=particular electrode)
    df_neuron_sim_emSim_i=df_neuron_sim[df_neuron_sim['EM_Sim']==sim_i]
    # Get the min and max titration factors for this Neuron simulation
    min_trit_factor_sim_i=np.min(df_neuron_sim_emSim_i['Titration Factor'])
    max_trit_factor_sim_i=np.max(df_neuron_sim_emSim_i['Titration Factor'])
    
    # Form the array of titration factors
    trit_array_sim_i=np.linspace(min_trit_factor_sim_i,max_trit_factor_sim_i,n_data_points) # n_data_points=100
    # Loop through the simulated roots (all roots (L1 - T12))
    for i_root in range(n_roots):
    # for i_root in [0]:
        root_i=roots[i_root]
        # Get the results for this particular root for this particular simulation (5 rootlets for roots, 10 fibres per rootlet (=50 data points))
        df_neuron_sim_emSim_i_root_i=df_neuron_sim_emSim_i[df_neuron_sim_emSim_i['Root']==root_i] 
       
        ## Compute the recruitment
        # Only get the titration factor
        trit_factors_sim_i_root_i=df_neuron_sim_emSim_i_root_i['Titration Factor']
        # Prepare the results array
        recruitment_sim_i_root_i=np.zeros(np.shape(trit_array_sim_i)) # for one elec all the tf
        n_fibers_in_sim_i_root_i=len(trit_factors_sim_i_root_i) # 50, 5rootlets a 10 fibers, for one root all the tf
        # Loop through values of titration between the min and the max of the sim
        # WHY do we define activation this way?
        # activation can be 0 bc min value might be in a different root
        # min sim is equals no activation max sim equals max
        for i_trit in range(n_data_points): # Number of points which represents the "amplitude"
            trit_i=trit_array_sim_i[i_trit]
            # For a specific root, how many rootlets are activated at certain level (= titration factor) ?
            n_active_trit_i= (df_neuron_sim_emSim_i_root_i['Titration Factor'] <= trit_i).sum()
            recruitment_sim_i_root_i[i_trit]=n_active_trit_i
        recruitment_sim_i_root_i=recruitment_sim_i_root_i/n_fibers_in_sim_i_root_i

        
        
        # Prepare the output csv
        d_rec_emSim_i_root_i = {'Trit_Array': trit_array_sim_i, 'Recruitment': recruitment_sim_i_root_i}
        df_recruitment_emSim_i_root_i = pd.DataFrame(data=d_rec_emSim_i_root_i)
        df_recruitment_emSim_i_root_i['Root']=root_i
        df_recruitment_emSim_i_root_i['EM_Sim']=sim_i
        spinal_level_df_fiber_i=""
        quadrant_df_fiber_i=""
        for spinal_level_i in spinal_levels:
            if spinal_level_i in root_df_fiber_i:
                spinal_level_df_fiber_i=spinal_level_i
                break
        df_recruitment_emSim_i_root_i['Spinal_Level']=spinal_level_df_fiber_i
        for quadrant_i in quadrants:
            if quadrant_i in root_df_fiber_i:
                quadrant_df_fiber_i=quadrant_i
                break
        df_recruitment_emSim_i_root_i['Quadrant']=quadrant_df_fiber_i
        
        ## Save the output csv
        # file_name="recruitment_sim_"+sim_i+"_root_"+root_i+".csv"
        # file_path=os.path.join(folder_output,file_name)
        # os.makedirs(folder_output,exist_ok=True)
        # df_recruitment_emSim_i_root_i.to_csv(file_path)
        print("##############################################")
        print(f"i_sim: {electrodes_from_listing[i_sim]}, i_root: {roots[i_root]}")
        recruitment_simulation[f"_{electrodes_from_listing[i_sim]}_{roots[i_root]}"] = df_recruitment_emSim_i_root_i
# Out:
# ##############################################
# i_sim: E00, i_root: T12_DL
# ##############################################
# i_sim: E00, i_root: T12_DR
# ##############################################
# i_sim: E00, i_root: L1_DL
# ##############################################
# i_sim: E00, i_root: L1_DR
# ##############################################
# i_sim: E00, i_root: L2_DL
# ##############################################
# i_sim: E00, i_root: L2_DR
# ##############################################
# i_sim: E00, i_root: L3_DL
# ##############################################
# i_sim: E00, i_root: L3_DR
# ##############################################
# i_sim: E00, i_root: L4_DL
# ##############################################
# i_sim: E00, i_root: L4_DR
# ##############################################
# i_sim: E00, i_root: L5_DL
# ##############################################
# i_sim: E00, i_root: L5_DR
# ##############################################
# i_sim: E00, i_root: S1_DL
# ##############################################
# i_sim: E00, i_root: S1_DR
# ##############################################
# i_sim: E00, i_root: S2_DL
# ##############################################
# i_sim: E00, i_root: S2_DR
# ##############################################
# i_sim: E00, i_root: S3_DL
# ##############################################
# i_sim: E00, i_root: S3_DR
# ##############################################
# i_sim: E00, i_root: S4_DL
# ##############################################
# i_sim: E00, i_root: S4_DR
# ##############################################
# i_sim: E01, i_root: T12_DL
# ##############################################
# i_sim: E01, i_root: T12_DR
# ##############################################
# i_sim: E01, i_root: L1_DL
# ##############################################
# i_sim: E01, i_root: L1_DR
# ##############################################
# i_sim: E01, i_root: L2_DL
# ##############################################
# i_sim: E01, i_root: L2_DR
# ##############################################
# i_sim: E01, i_root: L3_DL
# ##############################################
# i_sim: E01, i_root: L3_DR
# ##############################################
# i_sim: E01, i_root: L4_DL
# ##############################################
# i_sim: E01, i_root: L4_DR
# ##############################################
# i_sim: E01, i_root: L5_DL
# ##############################################
# i_sim: E01, i_root: L5_DR
# ##############################################
# i_sim: E01, i_root: S1_DL
# ##############################################
# i_sim: E01, i_root: S1_DR
# ##############################################
# i_sim: E01, i_root: S2_DL
# ##############################################
# i_sim: E01, i_root: S2_DR
# ##############################################
# i_sim: E01, i_root: S3_DL
# ##############################################
# i_sim: E01, i_root: S3_DR
# ##############################################
# i_sim: E01, i_root: S4_DL
# ##############################################
# i_sim: E01, i_root: S4_DR
# ##############################################
# i_sim: E02, i_root: T12_DL
# ##############################################
# i_sim: E02, i_root: T12_DR
# ##############################################
# i_sim: E02, i_root: L1_DL
# ##############################################
# i_sim: E02, i_root: L1_DR
# ##############################################
# i_sim: E02, i_root: L2_DL
# ##############################################
# i_sim: E02, i_root: L2_DR
# ##############################################
# i_sim: E02, i_root: L3_DL
# ##############################################
# i_sim: E02, i_root: L3_DR
# ##############################################
# i_sim: E02, i_root: L4_DL
# ##############################################
# i_sim: E02, i_root: L4_DR
# ##############################################
# i_sim: E02, i_root: L5_DL
# ##############################################
# i_sim: E02, i_root: L5_DR
# ##############################################
# i_sim: E02, i_root: S1_DL
# ##############################################
# i_sim: E02, i_root: S1_DR
# ##############################################
# i_sim: E02, i_root: S2_DL
# ##############################################
# i_sim: E02, i_root: S2_DR
# ##############################################
# i_sim: E02, i_root: S3_DL
# ##############################################
# i_sim: E02, i_root: S3_DR
# ##############################################
# i_sim: E02, i_root: S4_DL
# ##############################################
# i_sim: E02, i_root: S4_DR
# ##############################################
# i_sim: E03, i_root: T12_DL
# ##############################################
# i_sim: E03, i_root: T12_DR
# ##############################################
# i_sim: E03, i_root: L1_DL
# ##############################################
# i_sim: E03, i_root: L1_DR
# ##############################################
# i_sim: E03, i_root: L2_DL
# ##############################################
# i_sim: E03, i_root: L2_DR
# ##############################################
# i_sim: E03, i_root: L3_DL
# ##############################################
# i_sim: E03, i_root: L3_DR
# ##############################################
# i_sim: E03, i_root: L4_DL
# ##############################################
# i_sim: E03, i_root: L4_DR
# ##############################################
# i_sim: E03, i_root: L5_DL
# ##############################################
# i_sim: E03, i_root: L5_DR
# ##############################################
# i_sim: E03, i_root: S1_DL
# ##############################################
# i_sim: E03, i_root: S1_DR
# ##############################################
# i_sim: E03, i_root: S2_DL
# ##############################################
# i_sim: E03, i_root: S2_DR
# ##############################################
# i_sim: E03, i_root: S3_DL
# ##############################################
# i_sim: E03, i_root: S3_DR
# ##############################################
# i_sim: E03, i_root: S4_DL
# ##############################################
# i_sim: E03, i_root: S4_DR
# ##############################################
# i_sim: E04, i_root: T12_DL
# ##############################################
# i_sim: E04, i_root: T12_DR
# ##############################################
# i_sim: E04, i_root: L1_DL
# ##############################################
# i_sim: E04, i_root: L1_DR
# ##############################################
# i_sim: E04, i_root: L2_DL
# ##############################################
# i_sim: E04, i_root: L2_DR
# ##############################################
# i_sim: E04, i_root: L3_DL
# ##############################################
# i_sim: E04, i_root: L3_DR
# ##############################################
# i_sim: E04, i_root: L4_DL
# ##############################################
# i_sim: E04, i_root: L4_DR
# ##############################################
# i_sim: E04, i_root: L5_DL
# ##############################################
# i_sim: E04, i_root: L5_DR
# ##############################################
# i_sim: E04, i_root: S1_DL
# ##############################################
# i_sim: E04, i_root: S1_DR
# ##############################################
# i_sim: E04, i_root: S2_DL
# ##############################################
# i_sim: E04, i_root: S2_DR
# ##############################################
# i_sim: E04, i_root: S3_DL
# ##############################################
# i_sim: E04, i_root: S3_DR
# ##############################################
# i_sim: E04, i_root: S4_DL
# ##############################################
# i_sim: E04, i_root: S4_DR
# ##############################################
# i_sim: E05, i_root: T12_DL
# ##############################################
# i_sim: E05, i_root: T12_DR
# ##############################################
# i_sim: E05, i_root: L1_DL
# ##############################################
# i_sim: E05, i_root: L1_DR
# ##############################################
# i_sim: E05, i_root: L2_DL
# ##############################################
# i_sim: E05, i_root: L2_DR
# ##############################################
# i_sim: E05, i_root: L3_DL
# ##############################################
# i_sim: E05, i_root: L3_DR
# ##############################################
# i_sim: E05, i_root: L4_DL
# ##############################################
# i_sim: E05, i_root: L4_DR
# ##############################################
# i_sim: E05, i_root: L5_DL
# ##############################################
# i_sim: E05, i_root: L5_DR
# ##############################################
# i_sim: E05, i_root: S1_DL
# ##############################################
# i_sim: E05, i_root: S1_DR
# ##############################################
# i_sim: E05, i_root: S2_DL
# ##############################################
# i_sim: E05, i_root: S2_DR
# ##############################################
# i_sim: E05, i_root: S3_DL
# ##############################################
# i_sim: E05, i_root: S3_DR
# ##############################################
# i_sim: E05, i_root: S4_DL
# ##############################################
# i_sim: E05, i_root: S4_DR
# ##############################################
# i_sim: E06, i_root: T12_DL
# ##############################################
# i_sim: E06, i_root: T12_DR
# ##############################################
# i_sim: E06, i_root: L1_DL
# ##############################################
# i_sim: E06, i_root: L1_DR
# ##############################################
# i_sim: E06, i_root: L2_DL
# ##############################################
# i_sim: E06, i_root: L2_DR
# ##############################################
# i_sim: E06, i_root: L3_DL
# ##############################################
# i_sim: E06, i_root: L3_DR
# ##############################################
# i_sim: E06, i_root: L4_DL
# ##############################################
# i_sim: E06, i_root: L4_DR
# ##############################################
# i_sim: E06, i_root: L5_DL
# ##############################################
# i_sim: E06, i_root: L5_DR
# ##############################################
# i_sim: E06, i_root: S1_DL
# ##############################################
# i_sim: E06, i_root: S1_DR
# ##############################################
# i_sim: E06, i_root: S2_DL
# ##############################################
# i_sim: E06, i_root: S2_DR
# ##############################################
# i_sim: E06, i_root: S3_DL
# ##############################################
# i_sim: E06, i_root: S3_DR
# ##############################################
# i_sim: E06, i_root: S4_DL
# ##############################################
# i_sim: E06, i_root: S4_DR
# ##############################################
# i_sim: E07, i_root: T12_DL
# ##############################################
# i_sim: E07, i_root: T12_DR
# ##############################################
# i_sim: E07, i_root: L1_DL
# ##############################################
# i_sim: E07, i_root: L1_DR
# ##############################################
# i_sim: E07, i_root: L2_DL
# ##############################################
# i_sim: E07, i_root: L2_DR
# ##############################################
# i_sim: E07, i_root: L3_DL
# ##############################################
# i_sim: E07, i_root: L3_DR
# ##############################################
# i_sim: E07, i_root: L4_DL
# ##############################################
# i_sim: E07, i_root: L4_DR
# ##############################################
# i_sim: E07, i_root: L5_DL
# ##############################################
# i_sim: E07, i_root: L5_DR
# ##############################################
# i_sim: E07, i_root: S1_DL
# ##############################################
# i_sim: E07, i_root: S1_DR
# ##############################################
# i_sim: E07, i_root: S2_DL
# ##############################################
# i_sim: E07, i_root: S2_DR
# ##############################################
# i_sim: E07, i_root: S3_DL
# ##############################################
# i_sim: E07, i_root: S3_DR
# ##############################################
# i_sim: E07, i_root: S4_DL
# ##############################################
# i_sim: E07, i_root: S4_DR
# ##############################################
# i_sim: E08, i_root: T12_DL
# ##############################################
# i_sim: E08, i_root: T12_DR
# ##############################################
# i_sim: E08, i_root: L1_DL
# ##############################################
# i_sim: E08, i_root: L1_DR
# ##############################################
# i_sim: E08, i_root: L2_DL
# ##############################################
# i_sim: E08, i_root: L2_DR
# ##############################################
# i_sim: E08, i_root: L3_DL
# ##############################################
# i_sim: E08, i_root: L3_DR
# ##############################################
# i_sim: E08, i_root: L4_DL
# ##############################################
# i_sim: E08, i_root: L4_DR
# ##############################################
# i_sim: E08, i_root: L5_DL
# ##############################################
# i_sim: E08, i_root: L5_DR
# ##############################################
# i_sim: E08, i_root: S1_DL
# ##############################################
# i_sim: E08, i_root: S1_DR
# ##############################################
# i_sim: E08, i_root: S2_DL
# ##############################################
# i_sim: E08, i_root: S2_DR
# ##############################################
# i_sim: E08, i_root: S3_DL
# ##############################################
# i_sim: E08, i_root: S3_DR
# ##############################################
# i_sim: E08, i_root: S4_DL
# ##############################################
# i_sim: E08, i_root: S4_DR
# ##############################################
# i_sim: E09, i_root: T12_DL
# ##############################################
# i_sim: E09, i_root: T12_DR
# ##############################################
# i_sim: E09, i_root: L1_DL
# ##############################################
# i_sim: E09, i_root: L1_DR
# ##############################################
# i_sim: E09, i_root: L2_DL
# ##############################################
# i_sim: E09, i_root: L2_DR
# ##############################################
# i_sim: E09, i_root: L3_DL
# ##############################################
# i_sim: E09, i_root: L3_DR
# ##############################################
# i_sim: E09, i_root: L4_DL
# ##############################################
# i_sim: E09, i_root: L4_DR
# ##############################################
# i_sim: E09, i_root: L5_DL
# ##############################################
# i_sim: E09, i_root: L5_DR
# ##############################################
# i_sim: E09, i_root: S1_DL
# ##############################################
# i_sim: E09, i_root: S1_DR
# ##############################################
# i_sim: E09, i_root: S2_DL
# ##############################################
# i_sim: E09, i_root: S2_DR
# ##############################################
# i_sim: E09, i_root: S3_DL
# ##############################################
# i_sim: E09, i_root: S3_DR
# ##############################################
# i_sim: E09, i_root: S4_DL
# ##############################################
# i_sim: E09, i_root: S4_DR
# ##############################################
# i_sim: E10, i_root: T12_DL
# ##############################################
# i_sim: E10, i_root: T12_DR
# ##############################################
# i_sim: E10, i_root: L1_DL
# ##############################################
# i_sim: E10, i_root: L1_DR
# ##############################################
# i_sim: E10, i_root: L2_DL
# ##############################################
# i_sim: E10, i_root: L2_DR
# ##############################################
# i_sim: E10, i_root: L3_DL
# ##############################################
# i_sim: E10, i_root: L3_DR
# ##############################################
# i_sim: E10, i_root: L4_DL
# ##############################################
# i_sim: E10, i_root: L4_DR
# ##############################################
# i_sim: E10, i_root: L5_DL
# ##############################################
# i_sim: E10, i_root: L5_DR
# ##############################################
# i_sim: E10, i_root: S1_DL
# ##############################################
# i_sim: E10, i_root: S1_DR
# ##############################################
# i_sim: E10, i_root: S2_DL
# ##############################################
# i_sim: E10, i_root: S2_DR
# ##############################################
# i_sim: E10, i_root: S3_DL
# ##############################################
# i_sim: E10, i_root: S3_DR
# ##############################################
# i_sim: E10, i_root: S4_DL
# ##############################################
# i_sim: E10, i_root: S4_DR
# ##############################################
# i_sim: E11, i_root: T12_DL
# ##############################################
# i_sim: E11, i_root: T12_DR
# ##############################################
# i_sim: E11, i_root: L1_DL
# ##############################################
# i_sim: E11, i_root: L1_DR
# ##############################################
# i_sim: E11, i_root: L2_DL
# ##############################################
# i_sim: E11, i_root: L2_DR
# ##############################################
# i_sim: E11, i_root: L3_DL
# ##############################################
# i_sim: E11, i_root: L3_DR
# ##############################################
# i_sim: E11, i_root: L4_DL
# ##############################################
# i_sim: E11, i_root: L4_DR
# ##############################################
# i_sim: E11, i_root: L5_DL
# ##############################################
# i_sim: E11, i_root: L5_DR
# ##############################################
# i_sim: E11, i_root: S1_DL
# ##############################################
# i_sim: E11, i_root: S1_DR
# ##############################################
# i_sim: E11, i_root: S2_DL
# ##############################################
# i_sim: E11, i_root: S2_DR
# ##############################################
# i_sim: E11, i_root: S3_DL
# ##############################################
# i_sim: E11, i_root: S3_DR
# ##############################################
# i_sim: E11, i_root: S4_DL
# ##############################################
# i_sim: E11, i_root: S4_DR
# ##############################################
# i_sim: E12, i_root: T12_DL
# ##############################################
# i_sim: E12, i_root: T12_DR
# ##############################################
# i_sim: E12, i_root: L1_DL
# ##############################################
# i_sim: E12, i_root: L1_DR
# ##############################################
# i_sim: E12, i_root: L2_DL
# ##############################################
# i_sim: E12, i_root: L2_DR
# ##############################################
# i_sim: E12, i_root: L3_DL
# ##############################################
# i_sim: E12, i_root: L3_DR
# ##############################################
# i_sim: E12, i_root: L4_DL
# ##############################################
# i_sim: E12, i_root: L4_DR
# ##############################################
# i_sim: E12, i_root: L5_DL
# ##############################################
# i_sim: E12, i_root: L5_DR
# ##############################################
# i_sim: E12, i_root: S1_DL
# ##############################################
# i_sim: E12, i_root: S1_DR
# ##############################################
# i_sim: E12, i_root: S2_DL
# ##############################################
# i_sim: E12, i_root: S2_DR
# ##############################################
# i_sim: E12, i_root: S3_DL
# ##############################################
# i_sim: E12, i_root: S3_DR
# ##############################################
# i_sim: E12, i_root: S4_DL
# ##############################################
# i_sim: E12, i_root: S4_DR
# ##############################################
# i_sim: E13, i_root: T12_DL
# ##############################################
# i_sim: E13, i_root: T12_DR
# ##############################################
# i_sim: E13, i_root: L1_DL
# ##############################################
# i_sim: E13, i_root: L1_DR
# ##############################################
# i_sim: E13, i_root: L2_DL
# ##############################################
# i_sim: E13, i_root: L2_DR
# ##############################################
# i_sim: E13, i_root: L3_DL
# ##############################################
# i_sim: E13, i_root: L3_DR
# ##############################################
# i_sim: E13, i_root: L4_DL
# ##############################################
# i_sim: E13, i_root: L4_DR
# ##############################################
# i_sim: E13, i_root: L5_DL
# ##############################################
# i_sim: E13, i_root: L5_DR
# ##############################################
# i_sim: E13, i_root: S1_DL
# ##############################################
# i_sim: E13, i_root: S1_DR
# ##############################################
# i_sim: E13, i_root: S2_DL
# ##############################################
# i_sim: E13, i_root: S2_DR
# ##############################################
# i_sim: E13, i_root: S3_DL
# ##############################################
# i_sim: E13, i_root: S3_DR
# ##############################################
# i_sim: E13, i_root: S4_DL
# ##############################################
# i_sim: E13, i_root: S4_DR
# ##############################################
# i_sim: E14, i_root: T12_DL
# ##############################################
# i_sim: E14, i_root: T12_DR
# ##############################################
# i_sim: E14, i_root: L1_DL
# ##############################################
# i_sim: E14, i_root: L1_DR
# ##############################################
# i_sim: E14, i_root: L2_DL
# ##############################################
# i_sim: E14, i_root: L2_DR
# ##############################################
# i_sim: E14, i_root: L3_DL
# ##############################################
# i_sim: E14, i_root: L3_DR
# ##############################################
# i_sim: E14, i_root: L4_DL
# ##############################################
# i_sim: E14, i_root: L4_DR
# ##############################################
# i_sim: E14, i_root: L5_DL
# ##############################################
# i_sim: E14, i_root: L5_DR
# ##############################################
# i_sim: E14, i_root: S1_DL
# ##############################################
# i_sim: E14, i_root: S1_DR
# ##############################################
# i_sim: E14, i_root: S2_DL
# ##############################################
# i_sim: E14, i_root: S2_DR
# ##############################################
# i_sim: E14, i_root: S3_DL
# ##############################################
# i_sim: E14, i_root: S3_DR
# ##############################################
# i_sim: E14, i_root: S4_DL
# ##############################################
# i_sim: E14, i_root: S4_DR
# ##############################################
# i_sim: E15, i_root: T12_DL
# ##############################################
# i_sim: E15, i_root: T12_DR
# ##############################################
# i_sim: E15, i_root: L1_DL
# ##############################################
# i_sim: E15, i_root: L1_DR
# ##############################################
# i_sim: E15, i_root: L2_DL
# ##############################################
# i_sim: E15, i_root: L2_DR
# ##############################################
# i_sim: E15, i_root: L3_DL
# ##############################################
# i_sim: E15, i_root: L3_DR
# ##############################################
# i_sim: E15, i_root: L4_DL
# ##############################################
# i_sim: E15, i_root: L4_DR
# ##############################################
# i_sim: E15, i_root: L5_DL
# ##############################################
# i_sim: E15, i_root: L5_DR
# ##############################################
# i_sim: E15, i_root: S1_DL
# ##############################################
# i_sim: E15, i_root: S1_DR
# ##############################################
# i_sim: E15, i_root: S2_DL
# ##############################################
# i_sim: E15, i_root: S2_DR
# ##############################################
# i_sim: E15, i_root: S3_DL
# ##############################################
# i_sim: E15, i_root: S3_DR
# ##############################################
# i_sim: E15, i_root: S4_DL
# ##############################################
# i_sim: E15, i_root: S4_DR

# %%
df_electrodes_for_roots= pd.DataFrame(electrodes_from_listing, columns =['electrode_name'])
df_roots=pd.DataFrame(roots, columns =['root_name'])
                                              
df_electrodes_for_roots.to_csv('/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/df_electrodes_for_roots.csv')
df_roots.to_csv('/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/df_roots.csv')

fh = open('/Volumes/Extreme_SSD/Projectome_Estimation/root_simulations/recruitment_simulation_dump.pkl', "wb")
pickle.dump(recruitment_simulation, fh)
fh.close()

# %%
recruitment_simulation[f"_{'E15'}_{'S4_DR'}"]
# Out:
#     Trit_Array  Recruitment   Root EM_Sim Spinal_Level Quadrant
# 0    23.375000          0.0  S4_DR    E15          T12       DR
# 1    25.603535          0.0  S4_DR    E15          T12       DR
# 2    27.832071          0.0  S4_DR    E15          T12       DR
# 3    30.060606          0.0  S4_DR    E15          T12       DR
# 4    32.289141          0.0  S4_DR    E15          T12       DR
# ..         ...          ...    ...    ...          ...      ...
# 95  235.085859          1.0  S4_DR    E15          T12       DR
# 96  237.314394          1.0  S4_DR    E15          T12       DR
# 97  239.542929          1.0  S4_DR    E15          T12       DR
# 98  241.771465          1.0  S4_DR    E15          T12       DR
# 99  244.000000          1.0  S4_DR    E15          T12       DR
#
# [100 rows x 6 columns]
